# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_csv('Spotify_Youtube.csv')
df.keys()
# Out:
# Index(['Num', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Num    Artist                                        Url_spotify  \
# 0    0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1    1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2    2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3    3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4    4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5    5  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6    6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7    7  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8    8  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 9    9  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# 1                                    Rhinestone Eyes
# 2      New Gold (feat. Tame Impala and Bootie Brown)
# 3                                 On Melancholy Hill
# 4                                     Clint Eastwood
# 5                                               DARE
# 6  New Gold (feat. Tame Impala and Bootie Brown) ...
# 7                 She's My Collar (feat. Kali Uchis)
# 8                  Cracker Island (feat. Thundercat)
# 9                                        Dirty Harry
#
#                                                Album Album_type  \
# 0                                         Demon Days      album
# 1                                      Plastic Beach      album
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                      Plastic Beach      album
# 4                                           Gorillaz      album
# 5                                         Demon Days      album
# 6  New Gold (feat. Tame Impala and Bootie Brown) ...     single
# 7                                    Humanz (Deluxe)      album
# 8                  Cracker Island (feat. Thundercat)     single
# 9                                         Demon Days      album
#
#                                     Uri  Danceability  Energy   Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0  ...
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0  ...
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0  ...
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0  ...
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0  ...
# 5  spotify:track:4Hff1IjRbLGeLgFgxvHflk         0.760   0.891  11.0  ...
# 6  spotify:track:2c3KCGq6UojB2c8UAFrRON         0.716   0.897   4.0  ...
# 7  spotify:track:3lIxtCaROdRDuTnNBDm3n2         0.726   0.815  11.0  ...
# 8  spotify:track:2W3ZpQg9i6lE6kmHbcdu9N         0.741   0.913   2.0  ...
# 9  spotify:track:2bfGNzdiRa1jXZRdfssSzR         0.625   0.877  10.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1  https://www.youtube.com/watch?v=yYDmaexVHic
# 2  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4  https://www.youtube.com/watch?v=1V_xRb0x9aw
# 5  https://www.youtube.com/watch?v=uAOR6ib95kQ
# 6  https://www.youtube.com/watch?v=BONNm0F7Tto
# 7  https://www.youtube.com/watch?v=f8NwLXYIHS4
# 8  https://www.youtube.com/watch?v=S03T47hapAc
# 9  https://www.youtube.com/watch?v=cLnkQAeMbIM
#
#                                                Title     Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)    Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...    Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...    Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)    Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)    Gorillaz  618480958.0
# 5                   Gorillaz - DARE (Official Video)    Gorillaz  259021161.0
# 6  Gorillaz - New Gold ft. Tame Impala, Bootie Br...   Dom Dolla     451996.0
# 7                    Gorillaz - She's My Collar [HQ]  SalvaMuñox    1010982.0
# 8  Gorillaz - Cracker Island ft. Thundercat (Offi...    Gorillaz   24459820.0
# 9            Gorillaz - Dirty Harry (Official Video)    Gorillaz  154761056.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
# 5  1844658.0   72008.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 6    11686.0     241.0  Gorillaz 'New Gold' ft. Tame Impala, Bootie Br...
# 7    17675.0     260.0  𝐁̲𝐎̲𝐍̲𝐔̲𝐒̲:̲ Hu̳ma̳n̳z [̲̠̲𝐃̲̠̲𝐄̲̠̲𝐅̲̠̲𝐈̲̠̲𝐍̲̠...
# 8   739527.0   20296.0  Listen to Cracker Island: https://gorillaz.lnk...
# 9  1386920.0   39240.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
#
#    Licensed official_video        Stream
# 0      True           True  1.040235e+09
# 1      True           True  3.100837e+08
# 2      True           True  6.306347e+07
# 3      True           True  4.346636e+08
# 4      True           True  6.172597e+08
# 5      True           True  3.238503e+08
# 6     False           True  1.066615e+07
# 7     False          False  1.596059e+08
# 8      True           True  4.267190e+07
# 9      True           True  1.910747e+08
#
# [10 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Num               20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
#  16  Tempo             20716 non-null  float64
#  17  Duration_ms       20716 non-null  float64
#  18  Url_youtube       20248 non-null  object
#  19  Title             20248 non-null  object
#  20  Channel           20248 non-null  object
#  21  Views             20248 non-null  float64
#  22  Likes             20177 non-null  float64
#  23  Comments          20149 non-null  float64
#  24  Description       19842 non-null  object
#  25  Licensed          20248 non-null  object
#  26  official_video    20248 non-null  object
#  27  Stream            20142 non-null  float64
# dtypes: float64(15), int64(1), object(12)
# memory usage: 4.4+ MB

# %%
df.describe()
# Out:
#                 Num  Danceability        Energy           Key      Loudness  \
# count  20718.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean   10358.500000      0.619777      0.635250      5.300348     -7.671680
# std     5980.915774      0.165272      0.214147      3.576449      4.632749
# min        0.000000      0.000000      0.000020      0.000000    -46.251000
# 25%     5179.250000      0.518000      0.507000      2.000000     -8.858000
# 50%    10358.500000      0.637000      0.666000      5.000000     -6.536000
# 75%    15537.750000      0.740250      0.798000      8.000000     -4.931000
# max    20717.000000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness  \
# count  20716.000000  20716.000000      20716.000000  20716.000000
# mean       0.096456      0.291535          0.055962      0.193521
# std        0.111960      0.286299          0.193262      0.168531
# min        0.000000      0.000001          0.000000      0.014500
# 25%        0.035700      0.045200          0.000000      0.094100
# 50%        0.050500      0.193000          0.000002      0.125000
# 75%        0.103000      0.477250          0.000463      0.237000
# max        0.964000      0.996000          1.000000      1.000000
#
#             Valence         Tempo   Duration_ms         Views         Likes  \
# count  20716.000000  20716.000000  2.071600e+04  2.024800e+04  2.017700e+04
# mean       0.529853    120.638340  2.247176e+05  9.393782e+07  6.633411e+05
# std        0.245441     29.579018  1.247905e+05  2.746443e+08  1.789324e+06
# min        0.000000      0.000000  3.098500e+04  0.000000e+00  0.000000e+00
# 25%        0.339000     97.002000  1.800095e+05  1.826002e+06  2.158100e+04
# 50%        0.537000    119.965000  2.132845e+05  1.450110e+07  1.244810e+05
# 75%        0.726250    139.935000  2.524430e+05  7.039975e+07  5.221480e+05
# max        0.993000    243.372000  4.676058e+06  8.079649e+09  5.078865e+07
#
#            Comments        Stream
# count  2.014900e+04  2.014200e+04
# mean   2.751899e+04  1.359422e+08
# std    1.932347e+05  2.441321e+08
# min    0.000000e+00  6.574000e+03
# 25%    5.090000e+02  1.767486e+07
# 50%    3.277000e+03  4.968298e+07
# 75%    1.436000e+04  1.383581e+08
# max    1.608314e+07  3.386520e+09

# %% [markdown]
# # Data Cleaning

# %%
def rename_columns(df):
   df.columns = (df.columns
                  .str.replace('(?<=[a-z])(?=[A-Z])', '_', regex=True)
                  .str.lower()
               )
   df.columns = df.columns.str.replace(' ', '_')
   return df
df = rename_columns(df)

# %%
def reformat_song_names(df):
    df = df[~df['track'].str.contains(r'[^A-Za-z0-9\s\(\)]', na=False)]
    df.dropna(inplace=True)
    df = df[df['licensed'] == True]
    return df
df = reformat_song_names(df)

# %%
df.head()
# Out:
#    num    artist                                        url_spotify  \
# 1    1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3    3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4    4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5    5  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 9    9  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                 track          album album_type  \
# 1     Rhinestone Eyes  Plastic Beach      album
# 3  On Melancholy Hill  Plastic Beach      album
# 4      Clint Eastwood       Gorillaz      album
# 5                DARE     Demon Days      album
# 9         Dirty Harry     Demon Days      album
#
#                                     uri  danceability  energy   key  ...  \
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0  ...
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0  ...
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0  ...
# 5  spotify:track:4Hff1IjRbLGeLgFgxvHflk         0.760   0.891  11.0  ...
# 9  spotify:track:2bfGNzdiRa1jXZRdfssSzR         0.625   0.877  10.0  ...
#
#                                    url_youtube  \
# 1  https://www.youtube.com/watch?v=yYDmaexVHic
# 3  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4  https://www.youtube.com/watch?v=1V_xRb0x9aw
# 5  https://www.youtube.com/watch?v=uAOR6ib95kQ
# 9  https://www.youtube.com/watch?v=cLnkQAeMbIM
#
#                                                title   channel        views  \
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
# 5                   Gorillaz - DARE (Official Video)  Gorillaz  259021161.0
# 9            Gorillaz - Dirty Harry (Official Video)  Gorillaz  154761056.0
#
#        likes  comments                                        description  \
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
# 5  1844658.0   72008.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 9  1386920.0   39240.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
#
#    licensed official_video       stream
# 1      True           True  310083733.0
# 3      True           True  434663559.0
# 4      True           True  617259738.0
# 5      True           True  323850327.0
# 9      True           True  191074713.0
#
# [5 rows x 28 columns]

# %%
def classify_hits(df):

    views_threshold = df["views"].quantile(0.9)
    streams_threshold = df["stream"].quantile(0.9)

    df["hit"] = 0

    for index, row in df.iterrows():
        if row["views"] >= views_threshold and row["stream"] >= streams_threshold:
            df.at[index, "hit"] = 1

    return df
classify_hits(df)
# Out:
#          num       artist                                        url_spotify  \
# 1          1     Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3          3     Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4          4     Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5          5     Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 9          9     Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...      ...          ...                                                ...
# 20713  20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 track                           album  \
# 1                     Rhinestone Eyes                   Plastic Beach
# 3                  On Melancholy Hill                   Plastic Beach
# 4                      Clint Eastwood                        Gorillaz
# 5                                DARE                      Demon Days
# 9                         Dirty Harry                      Demon Days
# ...                               ...                             ...
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       album_type                                   uri  danceability  energy  \
# 1          album  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703
# 3          album  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739
# 4          album  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694
# 5          album  spotify:track:4Hff1IjRbLGeLgFgxvHflk         0.760   0.891
# 9          album  spotify:track:2bfGNzdiRa1jXZRdfssSzR         0.625   0.877
# ...          ...                                   ...           ...     ...
# 20713     single  spotify:track:0RtcKQGyI4hr8FgFH1TuYG         0.582   0.926
# 20714     single  spotify:track:3rHvPA8lUnPBkaLyPOc0VV         0.531   0.936
# 20715     single  spotify:track:4jk00YxPtPbhvHJE9N4ddv         0.443   0.830
# 20716     single  spotify:track:5EyErbpsugWliX006eTDex         0.417   0.767
# 20717     single  spotify:track:6lOn0jz1QpjcWeXo1oMm0k         0.498   0.938
#
#         key  ...                                              title  \
# 1       8.0  ...  Gorillaz - Rhinestone Eyes [Storyboard Film] (...
# 3       2.0  ...     Gorillaz - On Melancholy Hill (Official Video)
# 4      10.0  ...         Gorillaz - Clint Eastwood (Official Video)
# 5      11.0  ...                   Gorillaz - DARE (Official Video)
# 9      10.0  ...            Gorillaz - Dirty Harry (Official Video)
# ...     ...  ...                                                ...
# 20713   5.0  ...                               JUST DANCE HARDSTYLE
# 20714   4.0  ...                     SET FIRE TO THE RAIN HARDSTYLE
# 20715   4.0  ...                          OUTSIDE HARDSTYLE SPED UP
# 20716   9.0  ...                                ONLY GIRL HARDSTYLE
# 20717   6.0  ...                                 MISS YOU HARDSTYLE
#
#                    channel        views      likes  comments  \
# 1                 Gorillaz   72011645.0  1079128.0   31003.0
# 3                 Gorillaz  211754952.0  1788577.0   55229.0
# 4                 Gorillaz  618480958.0  6197318.0  155930.0
# 5                 Gorillaz  259021161.0  1844658.0   72008.0
# 9                 Gorillaz  154761056.0  1386920.0   39240.0
# ...                    ...          ...        ...       ...
# 20713  SICK LEGEND - Topic      71678.0     1113.0       0.0
# 20714  SICK LEGEND - Topic     164741.0     2019.0       0.0
# 20715  SICK LEGEND - Topic      35646.0      329.0       0.0
# 20716  SICK LEGEND - Topic       6533.0       88.0       0.0
# 20717  SICK LEGEND - Topic     158697.0     2484.0       0.0
#
#                                              description  licensed  \
# 1      The official video for Gorillaz - Rhinestone E...      True
# 3      Follow Gorillaz online:\nhttp://gorillaz.com \...      True
# 4      The official music video for Gorillaz - Clint ...      True
# 5      Follow Gorillaz online:\nhttp://gorillaz.com \...      True
# 9      Follow Gorillaz online:\nhttp://gorillaz.com \...      True
# ...                                                  ...       ...
# 20713  Provided to YouTube by Routenote\n\nJUST DANCE...      True
# 20714  Provided to YouTube by Routenote\n\nSET FIRE T...      True
# 20715  Provided to YouTube by Routenote\n\nOUTSIDE HA...      True
# 20716  Provided to YouTube by Routenote\n\nONLY GIRL ...      True
# 20717  Provided to YouTube by Routenote\n\nMISS YOU H...      True
#
#        official_video       stream hit
# 1                True  310083733.0   0
# 3                True  434663559.0   0
# 4                True  617259738.0   1
# 5                True  323850327.0   0
# 9                True  191074713.0   0
# ...               ...          ...  ..
# 20713            True    9227144.0   0
# 20714            True   10898176.0   0
# 20715            True    6226110.0   0
# 20716            True    6873961.0   0
# 20717            True    5695584.0   0
#
# [8349 rows x 29 columns]
